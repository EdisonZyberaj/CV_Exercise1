# %% [markdown]
# <a href="https://colab.research.google.com/github/EdisonZyberaj/CV_Exercise1/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the needed libraries
import matplotlib.pyplot as plt
import numpy as np
from skimage import data, img_as_uint
from skimage.util import random_noise
from skimage.filters import gaussian, prewitt
from skimage.data import binary_blobs
from skimage.morphology import erosion, disk
from skimage.color import rgb2gray
from scipy import ndimage
import math

# %%
# Task 1 - Load and display the coffee image

coffee = data.coffee()

plt.imshow(coffee)
plt.title("Coffee Image")
plt.axis("off")

print("Image shape:", coffee.shape)
# Out:
# Image shape: (400, 600, 3)
